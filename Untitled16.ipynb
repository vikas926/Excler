# %% [markdown]
# <a href="https://colab.research.google.com/github/vikas926/Excler/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install boto3

# %%
import boto3
# Create an S3 client
s3 = boto3.client("s3")

# %%
bucket_name = "mynlpmru6"
s3.create_bucket(
    Bucket=bucket_name,
    CreateBucketConfiguration={"LocationConstraint": "eu-north-1"}
)
print(f"Bucket '{bucket_name}' created successfully!")
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# <ipython-input-7-c01bcf265479> in <cell line: 0>()
#       1 bucket_name = "mynlpmru6"
# ----> 2 s3.create_bucket(
#       3     Bucket=bucket_name,
#       4     CreateBucketConfiguration={"LocationConstraint": "eu-north-1"}
#       5 )
#
# /usr/local/lib/python3.11/dist-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     568                 )
#     569             # The "self" in this scope is referring to the BaseClient.
# --> 570             return self._make_api_call(operation_name, kwargs)
#     571
#     572         _api_call.__name__ = str(py_operation_name)
#
# /usr/local/lib/python3.11/dist-packages/botocore/context.py in wrapper(*args, **kwargs)
#     122                 if hook:
#     123                     hook()
# --> 124                 return func(*args, **kwargs)
#     125
# ...

# %%
s3.upload_file("text.txt", "mynpmru", "data/testfile1.txt")
print("upload complete")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-ca4b39e7a0a7> in <cell line: 0>()
# ----> 1 s3.upload_file("text.txt", "mynpmru", "data/testfile1.txt")
#       2 print("upload complete")
#
# /usr/local/lib/python3.11/dist-packages/botocore/context.py in wrapper(*args, **kwargs)
#     122                 if hook:
#     123                     hook()
# --> 124                 return func(*args, **kwargs)
#     125
#     126         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/boto3/s3/inject.py in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     168     """
#     169     with S3Transfer(self, Config) as transfer:
# --> 170         return transfer.upload_file(
#     171             filename=Filename,
#     172             bucket=Bucket,
#
# ...

# %%
s3.download_file("mynlpmru", "data/testfile1.txt", "downloaded_test3.txt")
print("Download successful!")
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# <ipython-input-9-a4705711ba3c> in <cell line: 0>()
# ----> 1 s3.download_file("mynlpmru", "data/testfile1.txt", "downloaded_test3.txt")
#       2 print("Download successful!")
#
# /usr/local/lib/python3.11/dist-packages/botocore/context.py in wrapper(*args, **kwargs)
#     122                 if hook:
#     123                     hook()
# --> 124                 return func(*args, **kwargs)
#     125
#     126         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/boto3/s3/inject.py in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     216     """
#     217     with S3Transfer(self, Config) as transfer:
# --> 218         return transfer.download_file(
#     219             bucket=Bucket,
#     220             key=Key,
#
# ...

# %%
response = s3.list_objects_v2(Bucket="mynlpbucket2003")
print("Files in bucket:")
if "Contents" in response:
    for obj in response["Contents"]:
        print(f"- {obj['Key']} (Size: {obj['Size']} bytes)")
else:
    print("Bucket is empty.")
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# <ipython-input-10-9377720b7937> in <cell line: 0>()
# ----> 1 response = s3.list_objects_v2(Bucket="mynlpbucket2003")
#       2 print("Files in bucket:")
#       3 if "Contents" in response:
#       4     for obj in response["Contents"]:
#       5         print(f"- {obj['Key']} (Size: {obj['Size']} bytes)")
#
# /usr/local/lib/python3.11/dist-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     568                 )
#     569             # The "self" in this scope is referring to the BaseClient.
# --> 570             return self._make_api_call(operation_name, kwargs)
#     571
#     572         _api_call.__name__ = str(py_operation_name)
#
# /usr/local/lib/python3.11/dist-packages/botocore/context.py in wrapper(*args, **kwargs)
#     122                 if hook:
#     123                     hook()
# ...

# %%
s3.delete_object(Bucket="mynlpmru", Key="data/testfile1.txt")
print("File deleted successfully!")

# %%
s3.put_bucket_versioning(
    Bucket="mynlpmru",
    VersioningConfiguration={"Status": "Enabled"}
)
print("Bucket versioning enabled.")

# %%
copy_source = {"Bucket": "mynlpmru", "Key": "data/testfile.txt"}
s3.copy_object(CopySource=copy_source, Bucket="mynlpmru", Key="data/copied_testfile3.txt")
print("File copied successfully.")
